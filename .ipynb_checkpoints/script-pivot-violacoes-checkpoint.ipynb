# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import funcoes
pd.options.display.float_format = '{:.2f}'.format #para os números aparecerem com duas casas decimais
pd.set_option('display.max_columns', 50) #mostra 50 colunas ou o número desejado
pd.set_option('future.no_silent_downcasting', True)

dados = pd.read_excel("denuncias-2025.xlsx")
seg = dados.copy()
dados.shape
# Out:
# (96, 11)

# %%
funcoes.resumo(seg)
# Out:
# --- Formato ---
# (96, 11)
#
# --- Tipos de Dados ---
# Nº PROTOCOLO                    float64
# DATA                             object
# NOME DA VÍTIMA                   object
# SEXO                             object
# FAIXA ETÁRIA                     object
# RAÇA/COR                         object
# BAIRRO DA VÍTIMA                 object
# TIPO DE VIOLÊNCIA DENUNCIADA     object
# VÍNCULO DO SUSPEITO              object
# OBS.                             object
# DEVOLUTIVA                      float64
# dtype: object
#
# --- Valores Nulos ---
# Nº PROTOCOLO                     1
# DATA                             0
# NOME DA VÍTIMA                   0
# SEXO                             0
# FAIXA ETÁRIA                     0
# RAÇA/COR                         0
# BAIRRO DA VÍTIMA                 1
# TIPO DE VIOLÊNCIA DENUNCIADA     0
# VÍNCULO DO SUSPEITO              1
# OBS.                            95
# DEVOLUTIVA                      96
# dtype: int64
#
# --- Resumo Estatístico ---
#        Nº PROTOCOLO  DEVOLUTIVA
# count         95.00        0.00
# mean     3621022.60         NaN
# std       234466.70         NaN
# min      3286569.00         NaN
# 25%      3465021.00         NaN
# 50%      3610526.00         NaN
# 75%      3721030.00         NaN
# max      4190066.00         NaN

# %%
#renomeando colunas
seg.columns = ['protocolo', 'data', 'nome', 'sexo', 'faixa_etaria', 'cor', 'bairro', 'tipo_violencia', 'vínculo', 'obs', 'devolutiva']

# %%
#retirando caracteres como /, e, ;, -, 
seg['tipo_violencia'].unique()
seg['tipo_violencia'] = seg['tipo_violencia'].str.replace(r'[/;]', ', ', regex=True)
#alterando " e " por ', ' 
seg['tipo_violencia'] = seg['tipo_violencia'].str.replace(r'\s+e\s+', ', ', regex=True)

seg['tipo_violencia'] = seg['tipo_violencia'].str.replace(r'-', ' ', regex=True)

# %%
seg['tipo_violencia'].unique()
# Out:
# array(['Física, Psicológica, Psíquica, Patrimonial, Negligência, Abandono, Maus Tratos',
#        'Física, Psicológica, Psíquica, Negligência, Abandono, Maus Tratos',
#        'Psicológica, Psíquica, Patrimonial, Negligência, Abandono',
#        'Física, Psicológica, Psíquica, Moral, Negligência, Abandono, Maus Tratos',
#        'Psicológica, Psíquica, Negligência, Abandono, Maus Tratos',
#        'Psicológica, Psíquica', 'Física, Negligência, Abandono',
#        'Física, Psicológica, Psíquica, Maus Tratos',
#        'Negligência, Abandono',
#        'Psicológica, Psíquica, Patrimonial, Negligência, Abandono, Maus Tratos',
#        'Física, Psicológica, Psíquica, Patrimonial, Maus Tratos, Cárcere Privado',
#        'Patrimonial, Negligência, Abandono',
#        'Negligência, Abandono, Maus Tratos',
#        'Psicológica, Psíquica, Negligência, Abandono, Discriminação, Intolerância',
#        'Psicológica, Psíquica, Negligência, Abandono',
#        'Física, Negligência, Abandono, Direitos Civis, Políticos',
#        'Psicológica, Psíquica, Maus Tratos',
#        'Física, Negligência, Abandono, Maus Tratos',
#        'Física, Patrimonial, Negligência, Abandono, Maus Tratos',
#        'Patrimonial', 'Física, Patrimonial, Negligência, Abandono',
#        'Física, Psicológica, Psíquica, Patrimonial, Negligência, Abandono',
#        'Física, Psicológica, Psíquica, Moral, Maus Tratos',
#        'Psicológica, Psíquica, Negligência, Abandono, Cárcere Privado',
#        'Física, Maus Tratos, Negligência, Abandono',
#        'Física, Psicológica, Psíquica, Patrimonial, Maus Tratos',
#        'Psicológica, Psíquica, Patrimonial, Maus Tratos',
#        'Psicológica, Psíquica, Negligência, Abandono, Direitos Civis, Políticos',
#        'Física, Psicológica, Psíquica, Negligência, Abandono',
#        'Psicológica, Psíquica, Patrimonial, Negligência, Abandono, Maus Tratos, Direitos Civis, Políticos'],
#       dtype=object)

# %%
#separando tipo violencia por , e explodindo as linhas do data frame para cada observação de tipo_violencia separada da célula original
df_exp = seg.assign(tipo_violencia=seg['tipo_violencia'].str.split(',')).explode('tipo_violencia')
df_exp
# Out:
#     protocolo                 data                      nome sexo  \
# 0  3286569.00  2025-01-02 00:00:00                       Ana  Fem
# 0  3286569.00  2025-01-02 00:00:00                       Ana  Fem
# 0  3286569.00  2025-01-02 00:00:00                       Ana  Fem
# 0  3286569.00  2025-01-02 00:00:00                       Ana  Fem
# 0  3286569.00  2025-01-02 00:00:00                       Ana  Fem
# ..        ...                  ...                       ...  ...
# 94 4185244.00  2025-12-26 00:00:00  Luzia Celestina de Jesus  Fem
# 94 4185244.00  2025-12-26 00:00:00  Luzia Celestina de Jesus  Fem
# 94 4185244.00  2025-12-26 00:00:00  Luzia Celestina de Jesus  Fem
# 95 4190066.00  2025-12-30 00:00:00       Maria Alice Canesin  Fem
# 95 4190066.00  2025-12-30 00:00:00       Maria Alice Canesin  Fem
#
#    faixa_etaria     cor                            bairro   tipo_violencia  \
# 0           80+  Branca  Conjunto Residencial Cidade Alta           Física
# 0           80+  Branca  Conjunto Residencial Cidade Alta      Psicológica
# 0           80+  Branca  Conjunto Residencial Cidade Alta         Psíquica
# 0           80+  Branca  Conjunto Residencial Cidade Alta      Patrimonial
# 0           80+  Branca  Conjunto Residencial Cidade Alta      Negligência
# ..          ...     ...                               ...              ...
# 94          80+   Preta                               NaN      Maus Tratos
# 94          80+   Preta                               NaN   Direitos Civis
# 94          80+   Preta                               NaN        Políticos
# 95          70+  Branca                            Zona 7      Psicológica
# 95          70+  Branca                            Zona 7         Psíquica
#
#             vínculo                                  obs  devolutiva
# 0             Filha                                  NaN         NaN
# 0             Filha                                  NaN         NaN
# 0             Filha                                  NaN         NaN
# 0             Filha                                  NaN         NaN
# 0             Filha                                  NaN         NaN
# ..              ...                                  ...         ...
# 94              NaN  não é em maringá; devolver denuncia         NaN
# 94              NaN  não é em maringá; devolver denuncia         NaN
# 94              NaN  não é em maringá; devolver denuncia         NaN
# 95  Desconhecido(a)                                  NaN         NaN
# 95  Desconhecido(a)                                  NaN         NaN
#
# [471 rows x 11 columns]

# %%
df_exp['tipo_violencia'].unique()
# Out:
# array(['Física', ' Psicológica', ' Psíquica', ' Patrimonial',
#        ' Negligência', ' Abandono', ' Maus Tratos', 'Psicológica',
#        ' Moral', 'Negligência', ' Cárcere Privado', 'Patrimonial',
#        ' Discriminação', ' Intolerância', ' Direitos Civis', ' Políticos'],
#       dtype=object)

# %%
df_exp['tipo_violencia'].replace({
    ' Psicológica': 'Psicológica',
    ' Psíquica': 'Psicológica',
    ' Patrimonial': 'Patrimonial',
    ' Negligência': 'Negligência',
    ' Abandono': 'Abandono',
    ' Maus Tratos': 'Maus Tratos',
    ' Moral': 'Moral',
    ' Cárcere Privado': 'Cárcere Privado',
    ' Discriminação': 'Discriminação',
    'Intolerência': 'Intolerância',
    ' Direitos Civis': 'Direitos Civis',
    ' Políticos': 'Políticos'
}, inplace=True)
# Out:
# C:\Users\lucaspassoni\AppData\Local\Temp\ipykernel_11140\4126836423.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_exp['tipo_violencia'].replace({

# %%
df_exp.to_excel('df_exp.xlsx', index = False)

# %%
#agrupando os valores de tipo_violencia por bairro
contagem_por_bairro = df_exp.groupby('tipo_violencia')['bairro'].value_counts().sort_values(ascending=False).reset_index(name='Total')
contagem_por_bairro
# Out:
#     tipo_violencia                                 bairro  Total
# 0      Psicológica                       Vila Morangueira     18
# 1         Abandono                       Vila Morangueira      9
# 2      Negligência                       Vila Morangueira      9
# 3      Psicológica                        Jardim Alvorada      8
# 4      Psicológica         Parque Residencial Cidade Nova      8
# ..             ...                                    ...    ...
# 242    Negligência                     Conjunto Ney Braga      1
# 243    Negligência        Conjunto Residencial Champagnat      1
# 244    Negligência       Conjunto Residencial Cidade Alta      1
# 245    Negligência  Conjunto Residencial Parigot de Souza      1
# 246          Moral          Conjunto Habitacional Requião      1
#
# [247 rows x 3 columns]

# %%
#plotando o gráfico com sns.catplot, com os dados agrupados, (tipo_violencia)[bairro]
#mas quando tento escolher as 40 observações com maior número, ele retira alguns tipos de violência
#no caso onde o tipo de violência pode não aparecer registrado no bairro
plt.figure(figsize=(15, 10))
sns.catplot(data=contagem_por_bairro, kind='bar', x='Total', y='bairro', hue='tipo_violencia', height=6, aspect=1.5)
plt.title('Violência por Bairro e Tipo de Ocorrência')
plt.ylabel('Número de Ocorrências')
plt.xlabel('Bairro')
plt.xlim(0, 10)
plt.xticks(rotation=45)
plt.show()

# %%
#fazendo uma tabela dinâmica para separar tipo_violência em colunas e preencher valores vazios com 0
#para quando colocar no gráfico, aparecerem todas as legendas de tipo_violencia, caso algum valor do recorte seja 0
df_pivot = contagem_por_bairro.pivot_table(
    index = 'bairro',
    columns='tipo_violencia',
    values='Total',
    aggfunc='sum',
    fill_value=0 
)
#criando uma coluna total, somando as oorrencias por bairro
df_pivot['Total'] = df_pivot.sum(axis=1)
#exportando o df para excel
df_pivot.to_excel('df_pivot_denuncias_2025.xlsx', index=True)
#ordenando os valores por total
df_sorted = df_pivot.sort_values(by='Total', ascending=True)
#excluindo a coluna total, para não aparecer no gráfico
df_plot = df_sorted.drop(columns=['Total'])

df_plot
# Out:
# tipo_violencia                                      Abandono  Cárcere Privado  \
# bairro
# Jardim Montreal                                            0                0
# Jardim Real                                                0                0
# Zona 7                                                     0                0
# Vila Progresso                                             1                0
# Jardim Licce                                               0                0
# Zona 04                                                    1                0
# Conjunto Habitacional João de Barro Thaís                  0                0
# Conjunto Residencial Parigot de Souza                      1                0
# Jardim Lucianópolis                                        1                0
# Jardim Novo Oasis                                          1                0
# Jardim Olímpico                                            1                0
# Jardim São Silvestre                                       0                0
# Jardim Universo                                            1                0
# Loteamento Madrid                                          1                0
# Parque Residencial Tuiuti                                  1                0
# Parque das Bandeiras                                       1                0
# Parque das Laranjeiras                                     0                0
# Jardim Itália                                              1                0
# Jardim Dourados                                            1                0
# Jardim Monte Rei                                           1                0
# Jardim Colina Verde                                        1                0
# Conjunto Habitacional Pioneiro José Pires De Ol...         1                0
# Conjunto Residencial Paulino Carlos Filho                  1                0
# Jardim Imperial I                                          0                0
# Jardim Cidade Monções                                      1                0
# Jardim América                                             0                0
# Conjunto Habitacional Inocente Vila Nova Júnior            0                0
# Vila Operária                                              0                0
# Conjunto Habitacional Inocente Villanova Júnior            1                1
# Jardim Oriental                                            1                0
# Zona 06                                                    1                0
# Conjunto Batel                                             1                0
# Zona 02                                                    1                0
# Conjunto Ney Braga                                         1                0
# Jardim Seminário                                           1                0
# Jardim da Glória                                           1                0
# Jardim Pinheiro                                            1                0
# Jardim Império do Sol                                      1                0
# Jardim Internorte                                          1                0
# Jardim Alamar                                              1                0
# Centro                                                     1                0
# Não Informado                                              1                0
# Conjunto Residencial Cidade Alta                           1                0
# Conjunto Residencial Champagnat                            1                0
# Jardim Continental                                         1                0
# Parque Hortência                                           1                0
# Conjunto João de Barro Itaparica                           2                0
# Conjunto Habitacional Sanenge                              2                0
# Vila Santo Antônio                                         2                0
# Jardim Maravilha                                           1                0
# Vila Esperança                                             2                0
# Jardim Mandacaru                                           2                0
# Parque Residencial Aeroporto                               3                0
# Conjunto Habitacional Requião                              3                0
# Jardim das Estações                                        2                1
# Zona 07                                                    4                0
# Parque Residencial Cidade Nova                             4                0
# Jardim Alvorada                                            7                0
# Vila Morangueira                                           9                0
#
# tipo_violencia                                      Direitos Civis  \
# bairro
# Jardim Montreal                                                  0
# Jardim Real                                                      0
# Zona 7                                                           0
# Vila Progresso                                                   0
# Jardim Licce                                                     0
# Zona 04                                                          0
# Conjunto Habitacional João de Barro Thaís                        0
# Conjunto Residencial Parigot de Souza                            0
# Jardim Lucianópolis                                              0
# Jardim Novo Oasis                                                0
# Jardim Olímpico                                                  0
# Jardim São Silvestre                                             0
# Jardim Universo                                                  0
# Loteamento Madrid                                                0
# Parque Residencial Tuiuti                                        0
# Parque das Bandeiras                                             0
# Parque das Laranjeiras                                           0
# Jardim Itália                                                    0
# Jardim Dourados                                                  0
# Jardim Monte Rei                                                 0
# Jardim Colina Verde                                              0
# Conjunto Habitacional Pioneiro José Pires De Ol...               0
# Conjunto Residencial Paulino Carlos Filho                        0
# Jardim Imperial I                                                0
# Jardim Cidade Monções                                            0
# Jardim América                                                   0
# Conjunto Habitacional Inocente Vila Nova Júnior                  0
# Vila Operária                                                    0
# Conjunto Habitacional Inocente Villanova Júnior                  0
# Jardim Oriental                                                  0
# Zona 06                                                          0
# Conjunto Batel                                                   0
# Zona 02                                                          0
# Conjunto Ney Braga                                               0
# Jardim Seminário                                                 0
# Jardim da Glória                                                 0
# Jardim Pinheiro                                                  0
# Jardim Império do Sol                                            0
# Jardim Internorte                                                0
# Jardim Alamar                                                    0
# Centro                                                           0
# Não Informado                                                    0
# Conjunto Residencial Cidade Alta                                 0
# Conjunto Residencial Champagnat                                  0
# Jardim Continental                                               0
# Parque Hortência                                                 0
# Conjunto João de Barro Itaparica                                 0
# Conjunto Habitacional Sanenge                                    0
# Vila Santo Antônio                                               0
# Jardim Maravilha                                                 0
# Vila Esperança                                                   0
# Jardim Mandacaru                                                 0
# Parque Residencial Aeroporto                                     0
# Conjunto Habitacional Requião                                    0
# Jardim das Estações                                              0
# Zona 07                                                          0
# Parque Residencial Cidade Nova                                   0
# Jardim Alvorada                                                  1
# Vila Morangueira                                                 1
#
# tipo_violencia                                      Discriminação  Física  \
# bairro
# Jardim Montreal                                                 0       0
# Jardim Real                                                     0       0
# Zona 7                                                          0       0
# Vila Progresso                                                  0       0
# Jardim Licce                                                    0       0
# Zona 04                                                         0       1
# Conjunto Habitacional João de Barro Thaís                       0       0
# Conjunto Residencial Parigot de Souza                           0       0
# Jardim Lucianópolis                                             0       1
# Jardim Novo Oasis                                               0       0
# Jardim Olímpico                                                 0       0
# Jardim São Silvestre                                            0       1
# Jardim Universo                                                 0       1
# Loteamento Madrid                                               0       0
# Parque Residencial Tuiuti                                       0       0
# Parque das Bandeiras                                            0       0
# Parque das Laranjeiras                                          0       1
# Jardim Itália                                                   0       0
# Jardim Dourados                                                 0       0
# Jardim Monte Rei                                                0       0
# Jardim Colina Verde                                             0       0
# Conjunto Habitacional Pioneiro José Pires De Ol...              0       0
# Conjunto Residencial Paulino Carlos Filho                       0       0
# Jardim Imperial I                                               0       0
# Jardim Cidade Monções                                           0       0
# Jardim América                                                  0       1
# Conjunto Habitacional Inocente Vila Nova Júnior                 0       1
# Vila Operária                                                   0       0
# Conjunto Habitacional Inocente Villanova Júnior                 0       0
# Jardim Oriental                                                 0       0
# Zona 06                                                         0       0
# Conjunto Batel                                                  0       1
# Zona 02                                                         0       1
# Conjunto Ney Braga                                              0       1
# Jardim Seminário                                                0       1
# Jardim da Glória                                                0       1
# Jardim Pinheiro                                                 0       1
# Jardim Império do Sol                                           0       1
# Jardim Internorte                                               0       0
# Jardim Alamar                                                   0       1
# Centro                                                          0       1
# Não Informado                                                   0       1
# Conjunto Residencial Cidade Alta                                0       1
# Conjunto Residencial Champagnat                                 0       1
# Jardim Continental                                              0       1
# Parque Hortência                                                0       1
# Conjunto João de Barro Itaparica                                0       0
# Conjunto Habitacional Sanenge                                   0       0
# Vila Santo Antônio                                              0       0
# Jardim Maravilha                                                0       0
# Vila Esperança                                                  0       1
# Jardim Mandacaru                                                0       2
# Parque Residencial Aeroporto                                    0       1
# Conjunto Habitacional Requião                                   0       2
# Jardim das Estações                                             0       3
# Zona 07                                                         1       2
# Parque Residencial Cidade Nova                                  0       5
# Jardim Alvorada                                                 0       3
# Vila Morangueira                                                0       4
#
# tipo_violencia                                      Intolerância  Maus Tratos  \
# bairro
# Jardim Montreal                                                0            0
# Jardim Real                                                    0            0
# Zona 7                                                         0            0
# Vila Progresso                                                 0            0
# Jardim Licce                                                   0            0
# Zona 04                                                        0            0
# Conjunto Habitacional João de Barro Thaís                      0            1
# Conjunto Residencial Parigot de Souza                          0            0
# Jardim Lucianópolis                                            0            1
# Jardim Novo Oasis                                              0            0
# Jardim Olímpico                                                0            0
# Jardim São Silvestre                                           0            1
# Jardim Universo                                                0            0
# Loteamento Madrid                                              0            0
# Parque Residencial Tuiuti                                      0            0
# Parque das Bandeiras                                           0            0
# Parque das Laranjeiras                                         0            1
# Jardim Itália                                                  0            0
# Jardim Dourados                                                0            0
# Jardim Monte Rei                                               0            0
# Jardim Colina Verde                                            0            0
# Conjunto Habitacional Pioneiro José Pires De Ol...             0            0
# Conjunto Residencial Paulino Carlos Filho                      0            0
# Jardim Imperial I                                              0            1
# Jardim Cidade Monções                                          0            1
# Jardim América                                                 0            1
# Conjunto Habitacional Inocente Vila Nova Júnior                0            1
# Vila Operária                                                  0            1
# Conjunto Habitacional Inocente Villanova Júnior                0            0
# Jardim Oriental                                                0            0
# Zona 06                                                        0            1
# Conjunto Batel                                                 0            1
# Zona 02                                                        0            1
# Conjunto Ney Braga                                             0            1
# Jardim Seminário                                               0            0
# Jardim da Glória                                               0            1
# Jardim Pinheiro                                                0            1
# Jardim Império do Sol                                          0            1
# Jardim Internorte                                              0            1
# Jardim Alamar                                                  0            1
# Centro                                                         0            1
# Não Informado                                                  0            1
# Conjunto Residencial Cidade Alta                               0            1
# Conjunto Residencial Champagnat                                0            1
# Jardim Continental                                             0            1
# Parque Hortência                                               0            1
# Conjunto João de Barro Itaparica                               0            1
# Conjunto Habitacional Sanenge                                  0            2
# Vila Santo Antônio                                             0            1
# Jardim Maravilha                                               0            2
# Vila Esperança                                                 0            1
# Jardim Mandacaru                                               0            2
# Parque Residencial Aeroporto                                   0            1
# Conjunto Habitacional Requião                                  0            2
# Jardim das Estações                                            0            3
# Zona 07                                                        1            3
# Parque Residencial Cidade Nova                                 0            5
# Jardim Alvorada                                                0            6
# Vila Morangueira                                               0            5
#
# tipo_violencia                                      Moral  Negligência  \
# bairro
# Jardim Montreal                                         0            0
# Jardim Real                                             0            0
# Zona 7                                                  0            0
# Vila Progresso                                          0            1
# Jardim Licce                                            0            0
# Zona 04                                                 0            1
# Conjunto Habitacional João de Barro Thaís               0            0
# Conjunto Residencial Parigot de Souza                   0            1
# Jardim Lucianópolis                                     0            1
# Jardim Novo Oasis                                       0            1
# Jardim Olímpico                                         0            1
# Jardim São Silvestre                                    0            0
# Jardim Universo                                         0            1
# Loteamento Madrid                                       0            1
# Parque Residencial Tuiuti                               0            1
# Parque das Bandeiras                                    0            1
# Parque das Laranjeiras                                  0            0
# Jardim Itália                                           0            1
# Jardim Dourados                                         0            1
# Jardim Monte Rei                                        0            1
# Jardim Colina Verde                                     0            1
# Conjunto Habitacional Pioneiro José Pires De Ol...      0            1
# Conjunto Residencial Paulino Carlos Filho               0            1
# Jardim Imperial I                                       0            0
# Jardim Cidade Monções                                   0            1
# Jardim América                                          0            0
# Conjunto Habitacional Inocente Vila Nova Júnior         1            0
# Vila Operária                                           0            0
# Conjunto Habitacional Inocente Villanova Júnior         0            1
# Jardim Oriental                                         0            1
# Zona 06                                                 0            1
# Conjunto Batel                                          0            1
# Zona 02                                                 0            1
# Conjunto Ney Braga                                      0            1
# Jardim Seminário                                        0            1
# Jardim da Glória                                        0            1
# Jardim Pinheiro                                         0            1
# Jardim Império do Sol                                   0            1
# Jardim Internorte                                       0            1
# Jardim Alamar                                           0            1
# Centro                                                  0            1
# Não Informado                                           0            1
# Conjunto Residencial Cidade Alta                        0            1
# Conjunto Residencial Champagnat                         0            1
# Jardim Continental                                      1            1
# Parque Hortência                                        1            1
# Conjunto João de Barro Itaparica                        0            2
# Conjunto Habitacional Sanenge                           0            2
# Vila Santo Antônio                                      0            2
# Jardim Maravilha                                        0            1
# Vila Esperança                                          0            2
# Jardim Mandacaru                                        0            2
# Parque Residencial Aeroporto                            0            3
# Conjunto Habitacional Requião                           1            3
# Jardim das Estações                                     0            2
# Zona 07                                                 0            4
# Parque Residencial Cidade Nova                          2            4
# Jardim Alvorada                                         0            7
# Vila Morangueira                                        0            9
#
# tipo_violencia                                      Patrimonial  Políticos  \
# bairro
# Jardim Montreal                                               1          0
# Jardim Real                                                   1          0
# Zona 7                                                        0          0
# Vila Progresso                                                0          0
# Jardim Licce                                                  0          0
# Zona 04                                                       0          0
# Conjunto Habitacional João de Barro Thaís                     0          0
# Conjunto Residencial Parigot de Souza                         1          0
# Jardim Lucianópolis                                           0          0
# Jardim Novo Oasis                                             0          0
# Jardim Olímpico                                               0          0
# Jardim São Silvestre                                          0          0
# Jardim Universo                                               1          0
# Loteamento Madrid                                             0          0
# Parque Residencial Tuiuti                                     0          0
# Parque das Bandeiras                                          0          0
# Parque das Laranjeiras                                        0          0
# Jardim Itália                                                 0          0
# Jardim Dourados                                               0          0
# Jardim Monte Rei                                              0          0
# Jardim Colina Verde                                           0          0
# Conjunto Habitacional Pioneiro José Pires De Ol...            0          0
# Conjunto Residencial Paulino Carlos Filho                     0          0
# Jardim Imperial I                                             0          0
# Jardim Cidade Monções                                         0          0
# Jardim América                                                1          0
# Conjunto Habitacional Inocente Vila Nova Júnior               0          0
# Vila Operária                                                 0          0
# Conjunto Habitacional Inocente Villanova Júnior               0          0
# Jardim Oriental                                               1          0
# Zona 06                                                       1          0
# Conjunto Batel                                                0          0
# Zona 02                                                       0          0
# Conjunto Ney Braga                                            0          0
# Jardim Seminário                                              1          0
# Jardim da Glória                                              0          0
# Jardim Pinheiro                                               0          0
# Jardim Império do Sol                                         0          0
# Jardim Internorte                                             1          0
# Jardim Alamar                                                 0          0
# Centro                                                        0          0
# Não Informado                                                 1          0
# Conjunto Residencial Cidade Alta                              1          0
# Conjunto Residencial Champagnat                               1          0
# Jardim Continental                                            0          0
# Parque Hortência                                              0          0
# Conjunto João de Barro Itaparica                              0          0
# Conjunto Habitacional Sanenge                                 0          0
# Vila Santo Antônio                                            1          0
# Jardim Maravilha                                              2          0
# Vila Esperança                                                1          0
# Jardim Mandacaru                                              0          0
# Parque Residencial Aeroporto                                  0          0
# Conjunto Habitacional Requião                                 1          0
# Jardim das Estações                                           3          0
# Zona 07                                                       0          0
# Parque Residencial Cidade Nova                                0          0
# Jardim Alvorada                                               2          1
# Vila Morangueira                                              3          1
#
# tipo_violencia                                      Psicológica
# bairro
# Jardim Montreal                                               0
# Jardim Real                                                   0
# Zona 7                                                        2
# Vila Progresso                                                0
# Jardim Licce                                                  2
# Zona 04                                                       0
# Conjunto Habitacional João de Barro Thaís                     2
# Conjunto Residencial Parigot de Souza                         0
# Jardim Lucianópolis                                           0
# Jardim Novo Oasis                                             2
# Jardim Olímpico                                               2
# Jardim São Silvestre                                          2
# Jardim Universo                                               0
# Loteamento Madrid                                             2
# Parque Residencial Tuiuti                                     2
# Parque das Bandeiras                                          2
# Parque das Laranjeiras                                        2
# Jardim Itália                                                 2
# Jardim Dourados                                               2
# Jardim Monte Rei                                              2
# Jardim Colina Verde                                           2
# Conjunto Habitacional Pioneiro José Pires De Ol...            2
# Conjunto Residencial Paulino Carlos Filho                     2
# Jardim Imperial I                                             4
# Jardim Cidade Monções                                         2
# Jardim América                                                2
# Conjunto Habitacional Inocente Vila Nova Júnior               2
# Vila Operária                                                 4
# Conjunto Habitacional Inocente Villanova Júnior               2
# Jardim Oriental                                               2
# Zona 06                                                       2
# Conjunto Batel                                                2
# Zona 02                                                       2
# Conjunto Ney Braga                                            2
# Jardim Seminário                                              2
# Jardim da Glória                                              2
# Jardim Pinheiro                                               2
# Jardim Império do Sol                                         2
# Jardim Internorte                                             2
# Jardim Alamar                                                 2
# Centro                                                        2
# Não Informado                                                 2
# Conjunto Residencial Cidade Alta                              2
# Conjunto Residencial Champagnat                               2
# Jardim Continental                                            2
# Parque Hortência                                              4
# Conjunto João de Barro Itaparica                              4
# Conjunto Habitacional Sanenge                                 4
# Vila Santo Antônio                                            4
# Jardim Maravilha                                              4
# Vila Esperança                                                4
# Jardim Mandacaru                                              4
# Parque Residencial Aeroporto                                  6
# Conjunto Habitacional Requião                                 4
# Jardim das Estações                                           6
# Zona 07                                                       8
# Parque Residencial Cidade Nova                                8
# Jardim Alvorada                                               8
# Vila Morangueira                                             18

# %%
cores = [
    '#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4',
    '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', '#e6beff'
]

ax = df_plot.tail(5).plot(kind='barh', figsize=(12,10), edgecolor='black', linewidth=0.5, color=cores)
plt.title('5 bairros com mais ocorrências de Violência e Tipo de Ocorrência (2025)', fontsize=14)
plt.ylabel('Bairro', fontsize=14)
plt.xlabel('Número de Ocorrências', fontsize=14)
plt.xlim(0, 10)
plt.xticks(rotation=45)
ax.tick_params(axis='y', labelsize=16)
ax.legend(fontsize='x-large')
ax.set_xlim(0, 20)
plt.savefig('denuncias-por-bairro-2025.png', dpi=300, bbox_inches='tight')

# %%
# 3. Criar o gráfico de barras
ax = df_plot.tail(5).plot(kind='barh', figsize=(12, 7), width=0.8, edgecolor='black')

# 4. Adicionar rótulos (labels) em cima das barras
for container in ax.containers:
    ax.bar_label(container, padding=5)

# 5. Personalizações
plt.title('Denúncias por Bairro e Tipo', fontsize=15)
plt.xlabel('Quantidade de Denúncias', fontsize=12)
plt.ylabel('Bairro', fontsize=12)
plt.xticks(rotation=0) # Mantém nomes dos bairros na horizontal
plt.legend(title='Tipo de Denúncia', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# %%
contagem = df_exp['tipo_violencia'].value_counts(normalize=True, ascending=True) * 100

fig, ax = plt.subplots(figsize=(10,6))

ax.barh(contagem.index, contagem, color='#69b3a2', edgecolor = 'black')
ax.set_xlabel('Quantidade')
ax.set_ylabel('Tipo Violencia')
ax.set_xlim(0, 100)
ax.bar_label(ax.containers[0], fmt='%.0f%%', padding = 5)
# Out:
# [Text(5, 0, '0%'),
#  Text(5, 0, '0%'),
#  Text(5, 0, '0%'),
#  Text(5, 0, '1%'),
#  Text(5, 0, '1%'),
#  Text(5, 0, '1%'),
#  Text(5, 0, '6%'),
#  Text(5, 0, '9%'),
#  Text(5, 0, '13%'),
#  Text(5, 0, '17%'),
#  Text(5, 0, '17%'),
#  Text(5, 0, '36%')]
